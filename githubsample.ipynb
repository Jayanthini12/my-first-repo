# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayanthini12/my-first-repo/blob/main/githubsample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi GitHub Today I opened my account")
# Out:
# Hi GitHub Today I opened my account
